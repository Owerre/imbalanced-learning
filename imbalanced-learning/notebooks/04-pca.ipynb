# %% [markdown]
# #  Dimensionality Reduction with PCA

# %%
# %matplotlib inline

# Ignore deprecated warning
import warnings
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Set font scale and style
plt.rcParams.update({'font.size': 15})

from sklearn.model_selection import train_test_split

# %%
# Import custom classes
# %run -i '../src/helper/transfxn.py'
# %run -i '../src/helper/zimputer.py'

# %%
# Instantiate the classes
transfxn = TransformationPipeline()
imputer = DataFrameImputer()

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('../data/feat_engr_data.csv') # load cleaned data
print('Data size',df.shape) # data size
df.head()
# Out:
# Data size (6771768, 42)
#    c_year   c_mnth  c_wday  c_hour  class  c_vehs               c_conf c_rcfg  \
# 0    1999  January  Monday    20.0      0     2.0           Right turn    NaN
# 1    1999  January  Monday    20.0      0     2.0           Right turn    NaN
# 2    1999  January  Monday    20.0      0     2.0           Right turn    NaN
# 3    1999  January  Monday     8.0      0     1.0  Hit a moving object    NaN
# 4    1999  January  Monday     8.0      0     1.0  Hit a moving object    NaN
#
#                        c_wthr c_rsur  ... c_rcfg_ct hour_ct_per_day_ct  \
# 0             Clear and sunny    Icy  ...       NaN           0.278072
# 1             Clear and sunny    Icy  ...       NaN           0.278072
# 2             Clear and sunny    Icy  ...       NaN           0.278072
# 3  Freezing rain, sleet, hail   Snow  ...       NaN           0.391691
# 4  Freezing rain, sleet, hail   Snow  ...       NaN           0.391691
#
#    hour_ct_per_month_ct pisev_ct_per_hour_ct  conf_ct_per_hour_ct  \
# 0              0.434034            10.981478             0.268553
# 1              0.434034            10.981478             0.268553
# 2              0.434034            14.194474             0.268553
# 3              0.611380             7.796031             0.286598
# 4              0.611380            10.077019             0.286598
#
#    psafe_ct_per_hour_ct wthr_ct_per_hour_ct  vtype_ct_per_hour_ct  \
# 0                   NaN           18.938386              0.772580
# 1                   NaN           18.938386             22.330975
# 2             19.230057           18.938386             22.330975
# 3                   NaN            0.098990             15.853328
# 4                   NaN            0.098990                   NaN
#
#   rcfg_ct_per_hour_ct c_conf_ind
# 0                 NaN          N
# 1                 NaN          N
# 2                 NaN          N
# 3                 NaN          N
# 4                 NaN          N
#
# [5 rows x 42 columns]

# %% [markdown]
# # Reduce dataset

# %%
X1, X2, y1, y2 = train_test_split(df, df['class'], test_size = 0.1, random_state = 42, 
                                  stratify = df['class'])

# %% [markdown]
# # Create features matrix

# %%
# Feature matrix and class label
cols_to_drop = ['c_case', 'p_id', 'v_id', 'class']
X, y = X2.drop(cols_to_drop, axis = 1), X2['class']

# %%
# Re-encode the class variable
y.replace({0:'Non-fatal', 1: 'Fatal'}, inplace=True)

# %% [markdown]
# # Transformation pipeline

# %% [markdown]
# ## 1. Impute missing values

# %%
# Fit transform the training set
X_imputed = imputer.fit_transform(X)

# %% [markdown]
# ## 2. Pre-processing

# %%
# Transform and scale data
X_scaled, _, feat_nm = transfxn.preprocessing(X_imputed, X_imputed)

# %%
print('Data size after pre-processing:', X_scaled.shape)
# Out:
# Data size after pre-processing: (677177, 157)

# %% [markdown]
# # PCA plot

# %%
transfxn.pca_plot_labeled(X_scaled, y, palette = ['g', 'r'])
